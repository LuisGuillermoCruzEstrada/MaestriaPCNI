# %%
with open("APD_sequence_release_09142020.fasta.txt") as archivo:
    for linea in archivo:
        linea = linea.split(";")
        print(linea)
        break
# Out:
# ['>00001|Dermaseptin-B2 (XXA, DRS-B2,  Dermaseptin B2, DRS B2, DS bII, ADENOREGULIN', ' UCLL1c', '  frog, amphibians, animals)\n']
